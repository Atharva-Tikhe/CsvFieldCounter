# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('dummy_data.csv')

# %% [markdown]
# ## Automated Profile Report

# %%
profile = ProfileReport(df)
# profile

# %%
diff_val = list(pd.unique(df["number(num)"]))

sub_frame_list = []

for new_val in diff_val:
    sub_frame_list.append(df[df["number(num)"] == new_val])

# %%
# sub_frame_list[0]
# sub_frame_list[1]
# sub_frame_list[2]
sub_df = sub_frame_list[2]

# %% [markdown]
# ## Find Duplicate Rows

# %%
sub_df[sub_df.duplicated(subset = ['property_numeric_value','property_val_units','property_value'], keep = False)]
# Out:
#    number(num) SMILES(text)  inchi(num) compound(cat) mw(numeric)  \
# 13      123141       OCH(C)        22.0           GLY    property
# 14      123141       OCH(C)        22.0           GLY    property
#
#    property_name property_type property_value property_numeric_value  \
# 13             w            re           dup1                   dup1
# 14             p           re1           dup1                   dup1
#
#    property_val_units property_condition_db_value property_condition_units  \
# 13               dup1                        loll                       fs
# 14               dup1                       lolll                        f
#
#    mode of delivery species
# 13         921uk nc  casdce
# 14       kt jkhbkjb    cxdw

# %%
def append_text(elem):
    return elem + 791

def add_q_if_p(elem):
    if elem == 'p':
        return elem + 'q'
    else:
        return elem
    
def apply_nan(elem):
    if elem == r'/N':
        return np.nan
    else:
        return elem

# %%
df[df["species"] == "cxdw"]
# Out:
#    number(num) SMILES(text)  inchi(num) compound(cat) mw(numeric)  \
# 11      123141       OCH(C)        22.0           GLY    property
# 12      123141       OCH(C)        22.0           GLY    property
# 14      123141       OCH(C)        22.0           GLY    property
# 15      123141       OCH(C)        22.0           GLY    property
# 17      123141       OCH(C)        22.0           GLY   property2
#
#    property_name property_type property_value property_numeric_value  \
# 11             p           any              y               anything
# 12             p            TP             bb                 things
# 14             p           re1           dup1                   dup1
# 15             p            TP              b                    Nan
# 17             q           TP2              c                   \Nan
#
#    property_val_units property_condition_db_value property_condition_units  \
# 11                  d                        else                        f
# 12                  s                         lol                        f
# 14               dup1                       lolll                        f
# 15                  s                         lol                        f
# 17                 sq                         lol                        f
#
#    mode of delivery species
# 11         a ry3uY1    cxdw
# 12           ygjkhf    cxdw
# 14       kt jkhbkjb    cxdw
# 15        hg jgfred    cxdw
# 17        hg jgfred    cxdw

# %% [markdown]
# ## Apply a function to a column

# %%
# sub_df.iat[0,2] = 2314
# sub_df["inchi(num)"] = sub_df["inchi(num)"].apply(append_text)
# sub_df["property_name"] = sub_df["property_name"].apply(add_q_if_p)

# %%
df.iat[15, 8] = r'/N'
df.iat[16, 8] = r'/N'
df.iat[17, 8] = r'/N'
df
# Out:
#                                           number(num)   SMILES(text)  \
# 0                                              453218  COO=OCOO(CNH)
# 1                                              453218  COO=OCOO(CNH)
# 2                                              453218  COO=OCOO(CNH)
# 3                                              453218  COO=OCOO(CNH)
# 4                                              453218  COO=OCOO(CNH)
# 5                                              453218  COO=OCOO(CNH)
# 6                                              909921     C-OO=OCCOS
# 7                                              909921     C-OO=OCCOS
# 8                                              909921     C-OO=OCCOS
# 9                                              909921     C-OO=OCCOS
# 10                                             909921     C-OO=OCCOS
# 11                                             123141         OCH(C)
# 12                                             123141         OCH(C)
# 13                                             123141         OCH(C)
# 14                                             123141         OCH(C)
# 15                                             123141         OCH(C)
# 16                                             123141         OCH(C)
# 17                                             123141         OCH(C)
# 18  Beautiful is better than ugly.\nExplicit is be...            NaN
#
#     inchi(num) compound(cat) mw(numeric) property_name property_type  \
# 0        194.5      caffiene          87             x     something
# 1        194.5      caffiene       prop1             x     something
# 2        194.5      caffiene       prop3             a     something
# 3        194.5      caffiene       prop1             a     something
# 4        194.5      caffiene       prop1             a     something
# 5        194.5      caffiene       prop1             x     something
# 6         89.0   aldosterone       prop2             q           any
# 7         89.0   aldosterone       prop2             q           any
# 8         89.0   aldosterone       prop2             q           any
# 9         89.0   aldosterone       prop2             q           any
# 10        89.0   aldosterone       prop2             q           any
# 11        22.0           GLY    property             p           any
# 12        22.0           GLY    property             p            TP
# 13        22.0           GLY    property             w            re
# 14        22.0           GLY    property             p           re1
# 15        22.0           GLY    property             p            TP
# 16        22.0           GLY    property             p            TP
# 17        22.0           GLY   property2             q           TP2
# 18         NaN           NaN         NaN           NaN           NaN
#
#    property_value property_numeric_value property_val_units  \
# 0               y          somethingelse                  z
# 1               y          somethingelse                  z
# 2               y          somethingelse                  d
# 3               y          somethingelse                  d
# 4               y          somethingelse                  z
# 5               y          somethingelse                  d
# 6               y               anything                  d
# 7               y               anything                  d
# 8            dup1                   dup1               dup1
# 9               y               anything                  d
# 10              y               anything                  d
# 11              y               anything                  d
# 12             bb                 things                  s
# 13           dup1                   dup1               dup1
# 14           dup1                   dup1               dup1
# 15              b                     /N                  s
# 16             bc                     /N                  q
# 17              c                     /N                 sq
# 18            NaN                    NaN                NaN
#
#    property_condition_db_value property_condition_units  \
# 0                         else                        u
# 1                         else                        u
# 2                         else                        u
# 3                         else                        u
# 4                         else                        u
# 5                         else                        u
# 6                         else                        e
# 7                         else                        e
# 8                         else                        e
# 9                         else                        e
# 10                        else                        e
# 11                        else                        f
# 12                         lol                        f
# 13                        loll                       fs
# 14                       lolll                        f
# 15                         lol                        f
# 16                         lol                       fs
# 17                         lol                        f
# 18                         NaN                      NaN
#
#                                      mode of delivery      species
# 0                                                text         text
# 1                                               text2    skajdl kj
# 2                                             aksjd l    skajdl kj
# 3                                               lak c    skajdl kj
# 4                                             zlxkcj   aljshk cn s
# 5                                             zlxkcj      a ry3uY1
# 6                                            a ry3uY1         sadx
# 7   asdjak sd jdskf msd\nksdj flkjs f\nsij iej[p e...         sadx
# 8                                                 NaN         sadx
# 9                                             kn c,mx         sadx
# 10                                           921uk nc         sadx
# 11                                           a ry3uY1         cxdw
# 12                                             ygjkhf         cxdw
# 13                                           921uk nc       casdce
# 14                                         kt jkhbkjb         cxdw
# 15                                          hg jgfred         cxdw
# 16                                               asdx        zxc e
# 17                                          hg jgfred         cxdw
# 18                                                NaN          NaN

# %%
df["property_name"] = df["property_name"].apply(add_q_if_p)


# if inchi is even -> add 100
def change_inchi(elem):
    if elem % 2 == 0:
        return elem + 100
    else:
        return elem
    
df["inchi(num)"] = df["inchi(num)"].apply(change_inchi)

df["property_numeric_value"] = df["property_numeric_value"].apply(apply_nan)

df
# Out:
#                                           number(num)   SMILES(text)  \
# 0                                              453218  COO=OCOO(CNH)
# 1                                              453218  COO=OCOO(CNH)
# 2                                              453218  COO=OCOO(CNH)
# 3                                              453218  COO=OCOO(CNH)
# 4                                              453218  COO=OCOO(CNH)
# 5                                              453218  COO=OCOO(CNH)
# 6                                              909921     C-OO=OCCOS
# 7                                              909921     C-OO=OCCOS
# 8                                              909921     C-OO=OCCOS
# 9                                              909921     C-OO=OCCOS
# 10                                             909921     C-OO=OCCOS
# 11                                             123141         OCH(C)
# 12                                             123141         OCH(C)
# 13                                             123141         OCH(C)
# 14                                             123141         OCH(C)
# 15                                             123141         OCH(C)
# 16                                             123141         OCH(C)
# 17                                             123141         OCH(C)
# 18  Beautiful is better than ugly.\nExplicit is be...            NaN
#
#     inchi(num) compound(cat) mw(numeric) property_name property_type  \
# 0        194.5      caffiene          87             x     something
# 1        194.5      caffiene       prop1             x     something
# 2        194.5      caffiene       prop3             a     something
# 3        194.5      caffiene       prop1             a     something
# 4        194.5      caffiene       prop1             a     something
# 5        194.5      caffiene       prop1             x     something
# 6         89.0   aldosterone       prop2             q           any
# 7         89.0   aldosterone       prop2             q           any
# 8         89.0   aldosterone       prop2             q           any
# 9         89.0   aldosterone       prop2             q           any
# 10        89.0   aldosterone       prop2             q           any
# 11       122.0           GLY    property            pq           any
# 12       122.0           GLY    property            pq            TP
# 13       122.0           GLY    property             w            re
# 14       122.0           GLY    property            pq           re1
# 15       122.0           GLY    property            pq            TP
# 16       122.0           GLY    property            pq            TP
# 17       122.0           GLY   property2             q           TP2
# 18         NaN           NaN         NaN           NaN           NaN
#
#    property_value property_numeric_value property_val_units  \
# 0               y          somethingelse                  z
# 1               y          somethingelse                  z
# 2               y          somethingelse                  d
# 3               y          somethingelse                  d
# 4               y          somethingelse                  z
# 5               y          somethingelse                  d
# 6               y               anything                  d
# 7               y               anything                  d
# 8            dup1                   dup1               dup1
# 9               y               anything                  d
# 10              y               anything                  d
# 11              y               anything                  d
# 12             bb                 things                  s
# 13           dup1                   dup1               dup1
# 14           dup1                   dup1               dup1
# 15              b                    NaN                  s
# 16             bc                    NaN                  q
# 17              c                    NaN                 sq
# 18            NaN                    NaN                NaN
#
#    property_condition_db_value property_condition_units  \
# 0                         else                        u
# 1                         else                        u
# 2                         else                        u
# 3                         else                        u
# 4                         else                        u
# 5                         else                        u
# 6                         else                        e
# 7                         else                        e
# 8                         else                        e
# 9                         else                        e
# 10                        else                        e
# 11                        else                        f
# 12                         lol                        f
# 13                        loll                       fs
# 14                       lolll                        f
# 15                         lol                        f
# 16                         lol                       fs
# 17                         lol                        f
# 18                         NaN                      NaN
#
#                                      mode of delivery      species
# 0                                                text         text
# 1                                               text2    skajdl kj
# 2                                             aksjd l    skajdl kj
# 3                                               lak c    skajdl kj
# 4                                             zlxkcj   aljshk cn s
# 5                                             zlxkcj      a ry3uY1
# 6                                            a ry3uY1         sadx
# 7   asdjak sd jdskf msd\nksdj flkjs f\nsij iej[p e...         sadx
# 8                                                 NaN         sadx
# 9                                             kn c,mx         sadx
# 10                                           921uk nc         sadx
# 11                                           a ry3uY1         cxdw
# 12                                             ygjkhf         cxdw
# 13                                           921uk nc       casdce
# 14                                         kt jkhbkjb         cxdw
# 15                                          hg jgfred         cxdw
# 16                                               asdx        zxc e
# 17                                          hg jgfred         cxdw
# 18                                                NaN          NaN

# %%
"Atharva \"Tikhe\",mit"

# find and take out special chars using regex

df.iat[17,13] = "Atharva \"Tikhe\",mit"

# %%
df
# Out:
#                                           number(num)   SMILES(text)  \
# 0                                              453218  COO=OCOO(CNH)
# 1                                              453218  COO=OCOO(CNH)
# 2                                              453218  COO=OCOO(CNH)
# 3                                              453218  COO=OCOO(CNH)
# 4                                              453218  COO=OCOO(CNH)
# 5                                              453218  COO=OCOO(CNH)
# 6                                              909921     C-OO=OCCOS
# 7                                              909921     C-OO=OCCOS
# 8                                              909921     C-OO=OCCOS
# 9                                              909921     C-OO=OCCOS
# 10                                             909921     C-OO=OCCOS
# 11                                             123141         OCH(C)
# 12                                             123141         OCH(C)
# 13                                             123141         OCH(C)
# 14                                             123141         OCH(C)
# 15                                             123141         OCH(C)
# 16                                             123141         OCH(C)
# 17                                             123141         OCH(C)
# 18  Beautiful is better than ugly.\nExplicit is be...            NaN
#
#     inchi(num) compound(cat) mw(numeric) property_name property_type  \
# 0        194.5      caffiene          87             x     something
# 1        194.5      caffiene       prop1             x     something
# 2        194.5      caffiene       prop3             a     something
# 3        194.5      caffiene       prop1             a     something
# 4        194.5      caffiene       prop1             a     something
# 5        194.5      caffiene       prop1             x     something
# 6         89.0   aldosterone       prop2             q           any
# 7         89.0   aldosterone       prop2             q           any
# 8         89.0   aldosterone       prop2             q           any
# 9         89.0   aldosterone       prop2             q           any
# 10        89.0   aldosterone       prop2             q           any
# 11       122.0           GLY    property            pq           any
# 12       122.0           GLY    property            pq            TP
# 13       122.0           GLY    property             w            re
# 14       122.0           GLY    property            pq           re1
# 15       122.0           GLY    property            pq            TP
# 16       122.0           GLY    property            pq            TP
# 17       122.0           GLY   property2             q           TP2
# 18         NaN           NaN         NaN           NaN           NaN
#
#    property_value property_numeric_value property_val_units  \
# 0               y          somethingelse                  z
# 1               y          somethingelse                  z
# 2               y          somethingelse                  d
# 3               y          somethingelse                  d
# 4               y          somethingelse                  z
# 5               y          somethingelse                  d
# 6               y               anything                  d
# 7               y               anything                  d
# 8            dup1                   dup1               dup1
# 9               y               anything                  d
# 10              y               anything                  d
# 11              y               anything                  d
# 12             bb                 things                  s
# 13           dup1                   dup1               dup1
# 14           dup1                   dup1               dup1
# 15              b                    NaN                  s
# 16             bc                    NaN                  q
# 17              c                    NaN                 sq
# 18            NaN                    NaN                NaN
#
#    property_condition_db_value property_condition_units  \
# 0                         else                        u
# 1                         else                        u
# 2                         else                        u
# 3                         else                        u
# 4                         else                        u
# 5                         else                        u
# 6                         else                        e
# 7                         else                        e
# 8                         else                        e
# 9                         else                        e
# 10                        else                        e
# 11                        else                        f
# 12                         lol                        f
# 13                        loll                       fs
# 14                       lolll                        f
# 15                         lol                        f
# 16                         lol                       fs
# 17                         lol                        f
# 18                         NaN                      NaN
#
#                                      mode of delivery              species
# 0                                                text                 text
# 1                                               text2            skajdl kj
# 2                                             aksjd l            skajdl kj
# 3                                               lak c            skajdl kj
# 4                                             zlxkcj           aljshk cn s
# 5                                             zlxkcj              a ry3uY1
# 6                                            a ry3uY1                 sadx
# 7   asdjak sd jdskf msd\nksdj flkjs f\nsij iej[p e...                 sadx
# 8                                                 NaN                 sadx
# 9                                             kn c,mx                 sadx
# 10                                           921uk nc                 sadx
# 11                                           a ry3uY1                 cxdw
# 12                                             ygjkhf                 cxdw
# 13                                           921uk nc               casdce
# 14                                         kt jkhbkjb                 cxdw
# 15                                          hg jgfred                 cxdw
# 16                                               asdx                zxc e
# 17                                          hg jgfred  Atharva "Tikhe",mit
# 18                                                NaN                  NaN

# %% [markdown]
# ## Regular expression for finding special characters

# %%
df["property_condition_units"].str.match(r'^[a-zA-Z0-9]*$')
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18     NaN
# Name: property_condition_units, dtype: object

# %%
df["mode of delivery"].str.match(r'^[a-zA-Z0-9 ,]*$')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8       NaN
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18      NaN
# Name: mode of delivery, dtype: object

# %%
df.iat[7,12]
df["mode of delivery"]
# Out:
# 0                                                  text
# 1                                                 text2
# 2                                               aksjd l
# 3                                                 lak c
# 4                                               zlxkcj
# 5                                               zlxkcj
# 6                                              a ry3uY1
# 7     asdjak sd jdskf msd\nksdj flkjs f\nsij iej[p e...
# 8                                                   NaN
# 9                                               kn c,mx
# 10                                             921uk nc
# 11                                             a ry3uY1
# 12                                               ygjkhf
# 13                                             921uk nc
# 14                                           kt jkhbkjb
# 15                                            hg jgfred
# 16                                                 asdx
# 17                                            hg jgfred
# 18                                                  NaN
# Name: mode of delivery, dtype: object

# %%
def find_newline(elem):
    if r'\n' in elem:
        return

# %%
cols = df.columns
last_col = cols[len(cols)-1]

string = "something\n"
string[-1]


df
# Out:
#                                           number(num)   SMILES(text)  \
# 0                                              453218  COO=OCOO(CNH)
# 1                                              453218  COO=OCOO(CNH)
# 2                                              453218  COO=OCOO(CNH)
# 3                                              453218  COO=OCOO(CNH)
# 4                                              453218  COO=OCOO(CNH)
# 5                                              453218  COO=OCOO(CNH)
# 6                                              909921     C-OO=OCCOS
# 7                                              909921     C-OO=OCCOS
# 8                                              909921     C-OO=OCCOS
# 9                                              909921     C-OO=OCCOS
# 10                                             909921     C-OO=OCCOS
# 11                                             123141         OCH(C)
# 12                                             123141         OCH(C)
# 13                                             123141         OCH(C)
# 14                                             123141         OCH(C)
# 15                                             123141         OCH(C)
# 16                                             123141         OCH(C)
# 17                                             123141         OCH(C)
# 18  Beautiful is better than ugly.\nExplicit is be...            NaN
#
#     inchi(num) compound(cat) mw(numeric) property_name property_type  \
# 0        194.5      caffiene          87             x     something
# 1        194.5      caffiene       prop1             x     something
# 2        194.5      caffiene       prop3             a     something
# 3        194.5      caffiene       prop1             a     something
# 4        194.5      caffiene       prop1             a     something
# 5        194.5      caffiene       prop1             x     something
# 6         89.0   aldosterone       prop2             q           any
# 7         89.0   aldosterone       prop2             q           any
# 8         89.0   aldosterone       prop2             q           any
# 9         89.0   aldosterone       prop2             q           any
# 10        89.0   aldosterone       prop2             q           any
# 11       122.0           GLY    property            pq           any
# 12       122.0           GLY    property            pq            TP
# 13       122.0           GLY    property             w            re
# 14       122.0           GLY    property            pq           re1
# 15       122.0           GLY    property            pq            TP
# 16       122.0           GLY    property            pq            TP
# 17       122.0           GLY   property2             q           TP2
# 18         NaN           NaN         NaN           NaN           NaN
#
#    property_value property_numeric_value property_val_units  \
# 0               y          somethingelse                  z
# 1               y          somethingelse                  z
# 2               y          somethingelse                  d
# 3               y          somethingelse                  d
# 4               y          somethingelse                  z
# 5               y          somethingelse                  d
# 6               y               anything                  d
# 7               y               anything                  d
# 8            dup1                   dup1               dup1
# 9               y               anything                  d
# 10              y               anything                  d
# 11              y               anything                  d
# 12             bb                 things                  s
# 13           dup1                   dup1               dup1
# 14           dup1                   dup1               dup1
# 15              b                    NaN                  s
# 16             bc                    NaN                  q
# 17              c                    NaN                 sq
# 18            NaN                    NaN                NaN
#
#    property_condition_db_value property_condition_units  \
# 0                         else                        u
# 1                         else                        u
# 2                         else                        u
# 3                         else                        u
# 4                         else                        u
# 5                         else                        u
# 6                         else                        e
# 7                         else                        e
# 8                         else                        e
# 9                         else                        e
# 10                        else                        e
# 11                        else                        f
# 12                         lol                        f
# 13                        loll                       fs
# 14                       lolll                        f
# 15                         lol                        f
# 16                         lol                       fs
# 17                         lol                        f
# 18                         NaN                      NaN
#
#                                      mode of delivery  \
# 0                                                text
# 1                                               text2
# 2                                             aksjd l
# 3                                               lak c
# 4                                             zlxkcj
# 5                                             zlxkcj
# 6                                            a ry3uY1
# 7   asdjak sd jdskf msd\nksdj flkjs f\nsij iej[p e...
# 8                                                 NaN
# 9                                             kn c,mx
# 10                                           921uk nc
# 11                                           a ry3uY1
# 12                                             ygjkhf
# 13                                           921uk nc
# 14                                         kt jkhbkjb
# 15                                          hg jgfred
# 16                                               asdx
# 17                                          hg jgfred
# 18                                                NaN
#
#                                               species
# 0                                                text
# 1                                           skajdl kj
# 2                                           skajdl kj
# 3                                           skajdl kj
# 4                                         aljshk cn s
# 5                                            a ry3uY1
# 6                                                sadx
# 7                                                sadx
# 8                                                sadx
# 9                                                sadx
# 10                                               sadx
# 11                                               cxdw
# 12                                               cxdw
# 13                                             casdce
# 14                                               cxdw
# 15                                               cxdw
# 16  this is multiline comment \n wrapped by using ...
# 17  this is multiline comment \n wrapped by using ...
# 18                                      wrap continue
